# %% [markdown]
# ## GIBMS7015 Neural Network Assignment 1  (R version)##
# by HSING Chih-Chia (R08454015)
# 2020.Apr.02

# %% [markdown]
# ***
# #### Question 1 ####

# %%
b <- c(3,1,2)
dim(b) <- c(3,1)

C <- c(3,1,3,2,2,4,1,0,1)
dim(C) <- c(3,3)

onemat <- c(1,1,1)
dim(onemat) <- c(3,1)

# %%
a <- C%*%b + 5*onemat
a
# Out:
#      [,1]
# [1,] 18
# [2,] 10
# [3,] 20

# %% [markdown]
# ***
# #### Question 2 ####

# %%
d <- c(4,2,1)
dim(d) <- c(3,1)

# %%
a <- 3*d + C%*%b + 5*onemat
a
# Out:
#      [,1]
# [1,] 30
# [2,] 16
# [3,] 23

# %% [markdown]
# ***
# #### Question 3 ####
# Q3a) is computable

# %%
C/2
# Out:
#      [,1] [,2] [,3]
# [1,] 1.5  1    0.5
# [2,] 0.5  1    0.0
# [3,] 1.5  2    0.5

# %% [markdown]
# b) is not computable

# %%
C+d
# Out:
# Error in C + d:  適切な配列ではありません
# Traceback:

# %% [markdown]
# c) is computable

# %%
b%*%t(d)
# Out:
#      [,1] [,2] [,3]
# [1,] 12   6    3
# [2,]  4   2    1
# [3,]  8   4    2

# %% [markdown]
# d) is not computable

# %%
b%*%d
# Out:
# Error in b %*% d:  適切な引数ではありません
# Traceback:

# %% [markdown]
# e) is computable

# %%
C%*%(b+d)
# Out:
#      [,1]
# [1,] 30
# [2,] 13
# [3,] 36

# %% [markdown]
# ***
# #### Question 4 ####

# %%
E <- c(1,0,0,0,2,0,0,0,1)
dim(E) <- c(3,3)

F <- c(3,0,0,0,4,0,0,0,1)
dim(F) <- c(3,3)

# %%
G <- E %*% F
G

H <- F %*% E
H
# Out:
#      [,1] [,2] [,3]
# [1,] 3    0    0
# [2,] 0    8    0
# [3,] 0    0    1
#      [,1] [,2] [,3]
# [1,] 3    0    0
# [2,] 0    8    0
# [3,] 0    0    1

# %% [markdown]
# G is equal to H, this only works when E and F are both diagnal matrices.

# %%
identical(G,H)
# Out:
# [1] TRUE

# %% [markdown]
# #### Question 5 ####

# %%
v <- c(3,1,0)
dim(v) <- c(3,1)

u <- 1/(1+exp(-v))

# %%
u
# Out:
#      [,1]
# [1,] 0.9525741
# [2,] 0.7310586
# [3,] 0.5000000
