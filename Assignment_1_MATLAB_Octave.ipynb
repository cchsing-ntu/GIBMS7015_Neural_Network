% %% [markdown]
% ## GIBMS7015 Neural Network Assignment 1  (MATLAB/Octave version)##
% by HSING Chih-Chia(R08454015)
% 2020.Apr.02

% %% [markdown]
% ***
% #### Question 1: ####

% %%
b = [3;1;2];
C = [3,2,1;1,2,0;3,4,1];

a1 = C*b + 5*[1;1;1]
% Out:
% a1 =
%
%    18
%    10
%    20

% %% [markdown]
% ***
% #### Question 2 ####

% %%
d = [4;2;1];

a2 = 3*d + C*b + 5*1
% Out:
% a2 =
%
%    30
%    16
%    23

% %% [markdown]
% ***
% #### Question 3 ####
% a) C/2 is computable. Matrix operation with scalar value is mathematically possible.

% %%
C/2
% Out:
% ans =
%
%    1.50000   1.00000   0.50000
%    0.50000   1.00000   0.00000
%    1.50000   2.00000   0.50000

% %% [markdown]
% b) C+d is mathematically not computable, yet since 2016a MATLAB has made it possible with implicit expansion so it works now.

% %%
C+d
% Out:
% ans =
%
%    7   6   5
%    3   4   2
%    4   5   2

% %% [markdown]
% c) b*d' is computable, since the column of matrix b matches that of the row of matrix d'.

% %%
b*d'
% Out:
% ans =
%
%    12    6    3
%     4    2    1
%     8    4    2

% %% [markdown]
% d) b*d is not computable, since the column of matrix b does not match that of the row of matrix d'

% %%
b*d
% Out:
% error: operator *: nonconformant arguments (op1 is 3x1, op2 is 3x1)

% %% [markdown]
% e) C*(b+d) is computable, since the column of matrix C matches that of the row of matrix b+d

% %%
C*(b+d)
% Out:
% ans =
%
%    30
%    13
%    36

% %% [markdown]
% ***
% #### Question 4 ####

% %%
E = [1,0,0;0,2,0;0,0,1];
F = [3,0,0;0,4,0;0,0,1];

G = E*F
H = F*E
% Out:
% G =
%
%    3   0   0
%    0   8   0
%    0   0   1
%
% H =
%
%    3   0   0
%    0   8   0
%    0   0   1

% %% [markdown]
% G is equal to H, this only happens beacause E and F are both diagnal matrices.

% %% [markdown]
% ***
% #### Question 5 ####

% %%
v = [3,1,0];
u = zeros(length(v),1);
for i=1:3
    u(i) = 1/(1+exp(-v(i)));
end

u
% Out:
% u =
%
%    0.95257
%    0.73106
%    0.50000
